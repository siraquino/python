# %%
import pandas as pd

# %%
df = pd.read_csv('ejemplo_para_padybackfill.csv',index_col = 'Numero')
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %% [markdown]
# Para cambiar NaN por del dato Anterior

# %%
df.fillna(method='pad')
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       100.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.pad()
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       100.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.fillna(method='ffill')
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       100.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.ffill()
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       100.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df2 = pd.read_csv('ejemplo_para_padybackfill2.csv',index_col = 'Numero')
df2
# Out:
#            l1     l2   l3   l4
# Numero
# 1       100.0  200.0  300  400
# 2         NaN  200.0  300  400
# 3       111.0  200.0  300  400
# 4         1.0    2.0    3    4
# 5         5.0    4.0    3    2
# 6         3.0    NaN  300  400

# %%
df2.ffill()
# Out:
#            l1     l2   l3   l4
# Numero
# 1       100.0  200.0  300  400
# 2       100.0  200.0  300  400
# 3       111.0  200.0  300  400
# 4         1.0    2.0    3    4
# 5         5.0    4.0    3    2
# 6         3.0    4.0  300  400

# %% [markdown]
# Para cambiar NaN por del dato siguiente

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.fillna(method='backfill')
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       111.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.backfill()
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       111.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.fillna(method='bfill')
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       111.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2         NaN  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2

# %%
df.bfill()
# Out:
#            l1   l2   l3   l4
# Numero
# 1       100.0  200  300  400
# 2       111.0  200  300  400
# 3       111.0  200  300  400
# 4         1.0    2    3    4
# 5         5.0    4    3    2
